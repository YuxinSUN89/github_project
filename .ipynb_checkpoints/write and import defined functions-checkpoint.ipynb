# %%
#import pandas as pd
#import numpy as np
#import time
#from datetime import datetime
#import dask
#import dask.dataframe as dd

# %%
from pack.get_data import import_data, format_data

#from pack.format_data import format_data

# %%
dff=import_data()
dff.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-801108343dd2> in <module>
# ----> 1 dff=import_data()
#       2 dff.head()
#
# ~/Desktop/github/github project/pack/get_data.py in import_data()
#      13                                                                'Buyer ID ':float,'Bid Price':float,
#      14                                                                'Bid Size':float,'Ask Price':float,
# ---> 15                                                                'Ask Size':float,'Qualifiers':str})
#      16     return data
#      17
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dask/dataframe/io/csv.py in read(urlpath, blocksize, collection, lineterminator, compression, sample, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     576             storage_options=storage_options,
#     577             include_path_column=include_path_column,
# --> 578             **kwargs
#     579         )
#     580
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dask/dataframe/io/csv.py in read_pandas(reader, urlpath, blocksize, collection, lineterminator, compression, sample, enforce, assume_missing, storage_options, include_path_column, **kwargs)
#     403         compression=compression,
#     404         include_path=include_path_column,
# --> 405         **(storage_options or {})
#     406     )
#     407
#
# ~/opt/anaconda3/lib/python3.7/site-packages/dask/bytes/core.py in read_bytes(urlpath, delimiter, not_zero, blocksize, sample, compression, include_path, **kwargs)
#     119                     "To read, set blocksize=None"
#     120                 )
# --> 121             size = fs.info(path)["size"]
#     122             if size is None:
#     123                 raise ValueError(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/fsspec/implementations/local.py in info(self, path, **kwargs)
#      54     def info(self, path, **kwargs):
#      55         path = self._strip_protocol(path)
# ---> 56         out = os.stat(path, follow_symlinks=False)
#      57         dest = False
#      58         if os.path.islink(path):
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/Yuxin/Desktop/github/github project/practicepy.csv'

# %%
dff=format_data(dff)
dff.head()
# Out:
#     #RIC        Domain                        Date-Time  GMT Offset  \
# 0  AMP.N  Market Price 2006-06-06 11:00:17.869244+00:00          -4
# 1  AMP.N  Market Price 2006-06-06 13:30:56.169608+00:00          -4
# 2  AMP.N  Market Price 2006-06-06 13:30:56.449863+00:00          -4
# 3  AMP.N  Market Price 2006-06-06 13:30:57.715407+00:00          -4
# 4  AMP.N  Market Price 2006-06-06 13:30:58.212446+00:00          -4
#
#              Type  Price  Volume  Buyer ID  Bid Price  Bid Size  ...  \
# 0  Mkt. Condition    NaN     NaN       NaN        NaN       NaN  ...
# 1           Quote    NaN     NaN       NaN      45.21       6.0  ...
# 2           Trade  45.21  6300.0       NaN        NaN       NaN  ...
# 3           Quote    NaN     NaN       NaN      45.15       1.0  ...
# 4           Quote    NaN     NaN       NaN      45.15       1.0  ...
#
#    Ask Spread  Accumulated Ask Order Size Accumulated Bid Order Size  \
# 0         NaN                         NaN                        NaN
# 1         NaN                         NaN                        NaN
# 2         NaN                         NaN                        NaN
# 3         NaN                         NaN                        NaN
# 4         NaN                         NaN                        NaN
#
#   Average Price                            Date1  hour  minute  second  \
# 0           NaN 2006-06-06 11:00:17.869244+00:00    11       0      17
# 1           NaN 2006-06-06 13:30:56.169608+00:00    13      30      56
# 2           NaN 2006-06-06 13:30:56.449863+00:00    13      30      56
# 3           NaN 2006-06-06 13:30:57.715407+00:00    13      30      57
# 4           NaN 2006-06-06 13:30:58.212446+00:00    13      30      58
#
#                               date       date1
# 0 2006-06-06 11:00:17.869244+00:00  2006-06-06
# 1 2006-06-06 13:30:56.169608+00:00  2006-06-06
# 2 2006-06-06 13:30:56.449863+00:00  2006-06-06
# 3 2006-06-06 13:30:57.715407+00:00  2006-06-06
# 4 2006-06-06 13:30:58.212446+00:00  2006-06-06
#
# [5 rows x 27 columns]
